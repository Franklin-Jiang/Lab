# %%
from sortClass import cAlg
import random
import time
import numpy as np
import csv
import matplotlib.pyplot as plt

# %%
# timeArr is for counting and statics
timeArr = np.zeros((10,10,5))
scaleLst= [iNum for iNum in range(200,2001,200)]

for scaleId,scale in enumerate(scaleLst):
    # Initialize random array
    fD = [random.randint(-1e5,1e5) for _ in range(scale)]
    # Initialize Alg Class with iNum and fD
    MycAlg = cAlg(scale,fD)
    sortingFuncLst = [
        MycAlg.Alg_Sort1,
        MycAlg.Alg_Sort2,
        MycAlg.Alg_Sort3,
        MycAlg.Alg_Sort4,
        MycAlg.Alg_Sort5,
    ]

    # For each scale, program will carry out 10 tests 
    # to find the average performance 
    for testId in range(10):

        # For each test, program will run the 5 types of
        # sorting algorithm to distinc the differences
        for AlgId in range(5):

            start_time = time.time()
            sortingFuncLst[AlgId]()
            end_time = time.time()

            # Take record of the consumption time
            timeArr[scaleId,testId,AlgId] = end_time - start_time
            print(f'''
            Scale: {scale}
            Test: {testId}
            Alg: {AlgId}
            ''')
# Out:
#             Scale: 200
#             Test: 0
#             Alg: 0
#
#
#             Scale: 200
#             Test: 0
#             Alg: 1
#
#
#             Scale: 200
#             Test: 0
#             Alg: 2
#
#
#             Scale: 200
#             Test: 0
#             Alg: 3
#
#
#             Scale: 200
#             Test: 0
#             Alg: 4
#
#
#             Scale: 200
#             Test: 1
#             Alg: 0
#
#
#             Scale: 200
#             Test: 1
#             Alg: 1
#
#
#             Scale: 200
#             Test: 1
#             Alg: 2
#
#
#             Scale: 200
#             Test: 1
#             Alg: 3
#
#
#             Scale: 200
#             Test: 1
#             Alg: 4
#
#
#             Scale: 200
#             Test: 2
#             Alg: 0
#
#
#             Scale: 200
#             Test: 2
#             Alg: 1
#
#
#             Scale: 200
#             Test: 2
#             Alg: 2
#
#
#             Scale: 200
#             Test: 2
#             Alg: 3
#
#
#             Scale: 200
#             Test: 2
#             Alg: 4
#
#
#             Scale: 200
#             Test: 3
#             Alg: 0
#
#
#             Scale: 200
#             Test: 3
#             Alg: 1
#
#
#             Scale: 200
#             Test: 3
#             Alg: 2
#
#
#             Scale: 200
#             Test: 3
#             Alg: 3
#
#
#             Scale: 200
#             Test: 3
#             Alg: 4
#
#
#             Scale: 200
#             Test: 4
#             Alg: 0
#
#
#             Scale: 200
#             Test: 4
#             Alg: 1
#
#
#             Scale: 200
#             Test: 4
#             Alg: 2
#
#
#             Scale: 200
#             Test: 4
#             Alg: 3
#
#
#             Scale: 200
#             Test: 4
#             Alg: 4
#
#
#             Scale: 200
#             Test: 5
#             Alg: 0
#
#
#             Scale: 200
#             Test: 5
#             Alg: 1
#
#
#             Scale: 200
#             Test: 5
#             Alg: 2
#
#
#             Scale: 200
#             Test: 5
#             Alg: 3
#
#
#             Scale: 200
#             Test: 5
#             Alg: 4
#
#
#             Scale: 200
#             Test: 6
#             Alg: 0
#
#
#             Scale: 200
#             Test: 6
#             Alg: 1
#
#
#             Scale: 200
#             Test: 6
#             Alg: 2
#
#
#             Scale: 200
#             Test: 6
#             Alg: 3
#
#
#             Scale: 200
#             Test: 6
#             Alg: 4
#
#
#             Scale: 200
#             Test: 7
#             Alg: 0
#
#
#             Scale: 200
#             Test: 7
#             Alg: 1
#
#
#             Scale: 200
#             Test: 7
#             Alg: 2
#
#
#             Scale: 200
#             Test: 7
#             Alg: 3
#
#
#             Scale: 200
#             Test: 7
#             Alg: 4
#
#
#             Scale: 200
#             Test: 8
#             Alg: 0
#
#
#             Scale: 200
#             Test: 8
#             Alg: 1
#
#
#             Scale: 200
#             Test: 8
#             Alg: 2
#
#
#             Scale: 200
#             Test: 8
#             Alg: 3
#
#
#             Scale: 200
#             Test: 8
#             Alg: 4
#
#
#             Scale: 200
#             Test: 9
#             Alg: 0
#
#
#             Scale: 200
#             Test: 9
#             Alg: 1
#
#
#             Scale: 200
#             Test: 9
#             Alg: 2
#
#
#             Scale: 200
#             Test: 9
#             Alg: 3
#
#
#             Scale: 200
#             Test: 9
#             Alg: 4
#
#
#             Scale: 400
#             Test: 0
#             Alg: 0
#
#
#             Scale: 400
#             Test: 0
#             Alg: 1
#
#
#             Scale: 400
#             Test: 0
#             Alg: 2
#
#
#             Scale: 400
#             Test: 0
#             Alg: 3
#
#
#             Scale: 400
#             Test: 0
#             Alg: 4
#
#
#             Scale: 400
#             Test: 1
#             Alg: 0
#
#
#             Scale: 400
#             Test: 1
#             Alg: 1
#
#
#             Scale: 400
#             Test: 1
#             Alg: 2
#
#
#             Scale: 400
#             Test: 1
#             Alg: 3
#
#
#             Scale: 400
#             Test: 1
#             Alg: 4
#
#
#             Scale: 400
#             Test: 2
#             Alg: 0
#
#
#             Scale: 400
#             Test: 2
#             Alg: 1
#
#
#             Scale: 400
#             Test: 2
#             Alg: 2
#
#
#             Scale: 400
#             Test: 2
#             Alg: 3
#
#
#             Scale: 400
#             Test: 2
#             Alg: 4
#
#
#             Scale: 400
#             Test: 3
#             Alg: 0
#
#
#             Scale: 400
#             Test: 3
#             Alg: 1
#
#
#             Scale: 400
#             Test: 3
#             Alg: 2
#
#
#             Scale: 400
#             Test: 3
#             Alg: 3
#
#
#             Scale: 400
#             Test: 3
#             Alg: 4
#
#
#             Scale: 400
#             Test: 4
#             Alg: 0
#
#
#             Scale: 400
#             Test: 4
#             Alg: 1
#
#
#             Scale: 400
#             Test: 4
#             Alg: 2
#
#
#             Scale: 400
#             Test: 4
#             Alg: 3
#
#
#             Scale: 400
#             Test: 4
#             Alg: 4
#
#
#             Scale: 400
#             Test: 5
#             Alg: 0
#
#
#             Scale: 400
#             Test: 5
#             Alg: 1
#
#
#             Scale: 400
#             Test: 5
#             Alg: 2
#
#
#             Scale: 400
#             Test: 5
#             Alg: 3
#
#
#             Scale: 400
#             Test: 5
#             Alg: 4
#
#
#             Scale: 400
#             Test: 6
#             Alg: 0
#
#
#             Scale: 400
#             Test: 6
#             Alg: 1
#
#
#             Scale: 400
#             Test: 6
#             Alg: 2
#
#
#             Scale: 400
#             Test: 6
#             Alg: 3
#
#
#             Scale: 400
#             Test: 6
#             Alg: 4
#
#
#             Scale: 400
#             Test: 7
#             Alg: 0
#
#
#             Scale: 400
#             Test: 7
#             Alg: 1
#
#
#             Scale: 400
#             Test: 7
#             Alg: 2
#
#
#             Scale: 400
#             Test: 7
#             Alg: 3
#
#
#             Scale: 400
#             Test: 7
#             Alg: 4
#
#
#             Scale: 400
#             Test: 8
#             Alg: 0
#
#
#             Scale: 400
#             Test: 8
#             Alg: 1
#
#
#             Scale: 400
#             Test: 8
#             Alg: 2
#
#
#             Scale: 400
#             Test: 8
#             Alg: 3
#
#
#             Scale: 400
#             Test: 8
#             Alg: 4
#
#
#             Scale: 400
#             Test: 9
#             Alg: 0
#
#
#             Scale: 400
#             Test: 9
#             Alg: 1
#
#
#             Scale: 400
#             Test: 9
#             Alg: 2
#
#
#             Scale: 400
#             Test: 9
#             Alg: 3
#
#
#             Scale: 400
#             Test: 9
#             Alg: 4
#
#
#             Scale: 600
#             Test: 0
#             Alg: 0
#
#
#             Scale: 600
#             Test: 0
#             Alg: 1
#
#
#             Scale: 600
#             Test: 0
#             Alg: 2
#
#
#             Scale: 600
#             Test: 0
#             Alg: 3
#
#
#             Scale: 600
#             Test: 0
#             Alg: 4
#
#
#             Scale: 600
#             Test: 1
#             Alg: 0
#
#
#             Scale: 600
#             Test: 1
#             Alg: 1
#
#
#             Scale: 600
#             Test: 1
#             Alg: 2
#
#
#             Scale: 600
#             Test: 1
#             Alg: 3
#
#
#             Scale: 600
#             Test: 1
#             Alg: 4
#
#
#             Scale: 600
#             Test: 2
#             Alg: 0
#
#
#             Scale: 600
#             Test: 2
#             Alg: 1
#
#
#             Scale: 600
#             Test: 2
#             Alg: 2
#
#
#             Scale: 600
#             Test: 2
#             Alg: 3
#
#
#             Scale: 600
#             Test: 2
#             Alg: 4
#
#
#             Scale: 600
#             Test: 3
#             Alg: 0
#
#
#             Scale: 600
#             Test: 3
#             Alg: 1
#
#
#             Scale: 600
#             Test: 3
#             Alg: 2
#
#
#             Scale: 600
#             Test: 3
#             Alg: 3
#
#
#             Scale: 600
#             Test: 3
#             Alg: 4
#
#
#             Scale: 600
#             Test: 4
#             Alg: 0
#
#
#             Scale: 600
#             Test: 4
#             Alg: 1
#
#
#             Scale: 600
#             Test: 4
#             Alg: 2
#
#
#             Scale: 600
#             Test: 4
#             Alg: 3
#
#
#             Scale: 600
#             Test: 4
#             Alg: 4
#
#
#             Scale: 600
#             Test: 5
#             Alg: 0
#
#
#             Scale: 600
#             Test: 5
#             Alg: 1
#
#
#             Scale: 600
#             Test: 5
#             Alg: 2
#
#
#             Scale: 600
#             Test: 5
#             Alg: 3
#
#
#             Scale: 600
#             Test: 5
#             Alg: 4
#
#
#             Scale: 600
#             Test: 6
#             Alg: 0
#
#
#             Scale: 600
#             Test: 6
#             Alg: 1
#
#
#             Scale: 600
#             Test: 6
#             Alg: 2
#
#
#             Scale: 600
#             Test: 6
#             Alg: 3
#
#
#             Scale: 600
#             Test: 6
#             Alg: 4
#
#
#             Scale: 600
#             Test: 7
#             Alg: 0
#
#
#             Scale: 600
#             Test: 7
#             Alg: 1
#
#
#             Scale: 600
#             Test: 7
#             Alg: 2
#
#
#             Scale: 600
#             Test: 7
#             Alg: 3
#
#
#             Scale: 600
#             Test: 7
#             Alg: 4
#
#
#             Scale: 600
#             Test: 8
#             Alg: 0
#
#
#             Scale: 600
#             Test: 8
#             Alg: 1
#
#
#             Scale: 600
#             Test: 8
#             Alg: 2
#
#
#             Scale: 600
#             Test: 8
#             Alg: 3
#
#
#             Scale: 600
#             Test: 8
#             Alg: 4
#
#
#             Scale: 600
#             Test: 9
#             Alg: 0
#
#
#             Scale: 600
#             Test: 9
#             Alg: 1
#
#
#             Scale: 600
#             Test: 9
#             Alg: 2
#
#
#             Scale: 600
#             Test: 9
#             Alg: 3
#
#
#             Scale: 600
#             Test: 9
#             Alg: 4
#
#
#             Scale: 800
#             Test: 0
#             Alg: 0
#
#
#             Scale: 800
#             Test: 0
#             Alg: 1
#
#
#             Scale: 800
#             Test: 0
#             Alg: 2
#
#
#             Scale: 800
#             Test: 0
#             Alg: 3
#
#
#             Scale: 800
#             Test: 0
#             Alg: 4
#
#
#             Scale: 800
#             Test: 1
#             Alg: 0
#
#
#             Scale: 800
#             Test: 1
#             Alg: 1
#
#
#             Scale: 800
#             Test: 1
#             Alg: 2
#
#
#             Scale: 800
#             Test: 1
#             Alg: 3
#
#
#             Scale: 800
#             Test: 1
#             Alg: 4
#
#
#             Scale: 800
#             Test: 2
#             Alg: 0
#
#
#             Scale: 800
#             Test: 2
#             Alg: 1
#
#
#             Scale: 800
#             Test: 2
#             Alg: 2
#
#
#             Scale: 800
#             Test: 2
#             Alg: 3
#
#
#             Scale: 800
#             Test: 2
#             Alg: 4
#
#
#             Scale: 800
#             Test: 3
#             Alg: 0
#
#
#             Scale: 800
#             Test: 3
#             Alg: 1
#
#
#             Scale: 800
#             Test: 3
#             Alg: 2
#
#
#             Scale: 800
#             Test: 3
#             Alg: 3
#
#
#             Scale: 800
#             Test: 3
#             Alg: 4
#
#
#             Scale: 800
#             Test: 4
#             Alg: 0
#
#
#             Scale: 800
#             Test: 4
#             Alg: 1
#
#
#             Scale: 800
#             Test: 4
#             Alg: 2
#
#
#             Scale: 800
#             Test: 4
#             Alg: 3
#
#
#             Scale: 800
#             Test: 4
#             Alg: 4
#
#
#             Scale: 800
#             Test: 5
#             Alg: 0
#
#
#             Scale: 800
#             Test: 5
#             Alg: 1
#
#
#             Scale: 800
#             Test: 5
#             Alg: 2
#
#
#             Scale: 800
#             Test: 5
#             Alg: 3
#
#
#             Scale: 800
#             Test: 5
#             Alg: 4
#
#
#             Scale: 800
#             Test: 6
#             Alg: 0
#
#
#             Scale: 800
#             Test: 6
#             Alg: 1
#
#
#             Scale: 800
#             Test: 6
#             Alg: 2
#
#
#             Scale: 800
#             Test: 6
#             Alg: 3
#
#
#             Scale: 800
#             Test: 6
#             Alg: 4
#
#
#             Scale: 800
#             Test: 7
#             Alg: 0
#
#
#             Scale: 800
#             Test: 7
#             Alg: 1
#
#
#             Scale: 800
#             Test: 7
#             Alg: 2
#
#
#             Scale: 800
#             Test: 7
#             Alg: 3
#
#
#             Scale: 800
#             Test: 7
#             Alg: 4
#
#
#             Scale: 800
#             Test: 8
#             Alg: 0
#
#
#             Scale: 800
#             Test: 8
#             Alg: 1
#
#
#             Scale: 800
#             Test: 8
#             Alg: 2
#
#
#             Scale: 800
#             Test: 8
#             Alg: 3
#
#
#             Scale: 800
#             Test: 8
#             Alg: 4
#
#
#             Scale: 800
#             Test: 9
#             Alg: 0
#
#
#             Scale: 800
#             Test: 9
#             Alg: 1
#
#
#             Scale: 800
#             Test: 9
#             Alg: 2
#
#
#             Scale: 800
#             Test: 9
#             Alg: 3
#
#
#             Scale: 800
#             Test: 9
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 0
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 0
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 0
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 0
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 0
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 1
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 1
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 1
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 1
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 1
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 2
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 2
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 2
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 2
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 2
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 3
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 3
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 3
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 3
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 3
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 4
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 4
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 4
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 4
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 4
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 5
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 5
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 5
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 5
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 5
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 6
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 6
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 6
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 6
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 6
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 7
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 7
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 7
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 7
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 7
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 8
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 8
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 8
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 8
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 8
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 9
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 9
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 9
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 9
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 9
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 0
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 0
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 0
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 0
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 0
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 1
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 1
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 1
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 1
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 1
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 2
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 2
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 2
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 2
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 2
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 3
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 3
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 3
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 3
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 3
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 4
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 4
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 4
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 4
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 4
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 5
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 5
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 5
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 5
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 5
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 6
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 6
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 6
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 6
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 6
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 7
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 7
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 7
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 7
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 7
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 8
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 8
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 8
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 8
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 8
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 9
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 9
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 9
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 9
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 9
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 0
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 0
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 0
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 0
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 0
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 1
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 1
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 1
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 1
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 1
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 2
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 2
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 2
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 2
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 2
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 3
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 3
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 3
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 3
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 3
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 4
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 4
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 4
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 4
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 4
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 5
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 5
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 5
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 5
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 5
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 6
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 6
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 6
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 6
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 6
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 7
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 7
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 7
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 7
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 7
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 8
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 8
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 8
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 8
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 8
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 9
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 9
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 9
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 9
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 9
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 0
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 0
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 0
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 0
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 0
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 1
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 1
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 1
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 1
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 1
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 2
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 2
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 2
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 2
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 2
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 3
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 3
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 3
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 3
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 3
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 4
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 4
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 4
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 4
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 4
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 5
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 5
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 5
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 5
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 5
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 6
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 6
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 6
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 6
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 6
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 7
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 7
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 7
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 7
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 7
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 8
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 8
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 8
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 8
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 8
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 9
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 9
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 9
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 9
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 9
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 0
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 0
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 0
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 0
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 0
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 1
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 1
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 1
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 1
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 1
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 2
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 2
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 2
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 2
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 2
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 3
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 3
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 3
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 3
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 3
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 4
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 4
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 4
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 4
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 4
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 5
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 5
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 5
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 5
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 5
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 6
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 6
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 6
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 6
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 6
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 7
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 7
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 7
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 7
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 7
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 8
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 8
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 8
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 8
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 8
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 9
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 9
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 9
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 9
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 9
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 0
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 0
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 0
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 0
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 0
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 1
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 1
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 1
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 1
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 1
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 2
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 2
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 2
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 2
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 2
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 3
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 3
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 3
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 3
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 3
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 4
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 4
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 4
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 4
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 4
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 5
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 5
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 5
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 5
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 5
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 6
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 6
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 6
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 6
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 6
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 7
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 7
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 7
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 7
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 7
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 8
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 8
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 8
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 8
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 8
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 9
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 9
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 9
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 9
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 9
#             Alg: 4

# %%
# Get the record and plot the result
avgTimeArr=np.zeros((5,10))
for algId in range(5):
    for scaleId in range(10):
        avgTimeArr[algId,scaleId] = timeArr[scaleId,:,algId].mean()
    plt.plot(scaleLst, avgTimeArr[algId,:])

with open('time.csv') as f:
    time_csv=csv.writer(f)
    time_csv.writerows(avgTimeArr)






# scale=2000
# # Initialize random array
# fD = [random.randint(-1e5,1e5) for _ in range(scale)]
# # Initialize Alg Class with iNum and fD
# MycAlg = cAlg(scale,fD)


# MycAlg.Alg_Sort1()
# print(MycAlg.fD)
# print(MycAlg.fD==sorted(MycAlg.fD))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\Codes\Python_Homework\Algorithm\Lab\sortMain.py in line 9
#       <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=51'>52</a>         avgTimeArr[algId,scaleId] = timeArr[scaleId,:,algId].mean()
#       <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=52'>53</a>     plt.plot(scaleLst, avgTimeArr[algId,:])
# ----> <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=54'>55</a> with open('time.csv') as f:
#      <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=55'>56</a>     time_csv=csv.writer(f)
#      <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=56'>57</a>     time_csv.writerows(avgTimeArr)
#
# File c:\Users\Redmibook_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=274'>275</a> if file in {0, 1, 2}:
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=275'>276</a>     raise ValueError(
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=276'>277</a>         f"IPython won't let you open fd={file} by default "
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=277'>278</a>         "as it is likely to crash IPython. If you know what you are doing, "
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=278'>279</a>         "you can use builtins' open."
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=279'>280</a>     )
# --> <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=281'>282</a> return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'time.csv'

# %%
# Get the record and plot the result
avgTimeArr=np.zeros((5,10))
for algId in range(5):
    for scaleId in range(10):
        avgTimeArr[algId,scaleId] = timeArr[scaleId,:,algId].mean()
    plt.plot(scaleLst, avgTimeArr[algId,:])

with open('time.csv','x',encoding='utf-8') as f:
    time_csv=csv.writer(f)
    time_csv.writerows(avgTimeArr)






# scale=2000
# # Initialize random array
# fD = [random.randint(-1e5,1e5) for _ in range(scale)]
# # Initialize Alg Class with iNum and fD
# MycAlg = cAlg(scale,fD)


# MycAlg.Alg_Sort1()
# print(MycAlg.fD)
# print(MycAlg.fD==sorted(MycAlg.fD))

# %%
# timeArr is for counting and statics
timeArr = np.zeros((10,10,5))
scaleLst= [iNum for iNum in range(200,2001,200)]
MycAlg = cAlg(0,[])
sortingFuncLst = [
        MycAlg.Alg_Sort1,
        MycAlg.Alg_Sort2,
        MycAlg.Alg_Sort3,
        MycAlg.Alg_Sort4,
        MycAlg.Alg_Sort5,
    ]


for scaleId, scale in enumerate(scaleLst):

    # For each scale, program will carry out 10 tests 
    # to find the average performance 
    for testId in range(10):

        # Initialize random array
        fD = [random.randint(-1e5,1e5) for _ in range(scale)]

        # For each test, program will run the 5 types of
        # sorting algorithm to distinc the differences
        for AlgId in range(5):

            # Initialize Alg Class with iNum and fD
            MycAlg.set_fD(scale,fD)

            start_time = time.time()
            sortingFuncLst[AlgId]()
            end_time = time.time()

            # Take record of the consumption time
            timeArr[scaleId,testId,AlgId] = end_time - start_time
            
            print(f'''
            Scale: {scale}
            Test: {testId}
            Alg: {AlgId}
            ''')
# Out:
#             Scale: 200
#             Test: 0
#             Alg: 0
#
#
#             Scale: 200
#             Test: 0
#             Alg: 1
#
#
#             Scale: 200
#             Test: 0
#             Alg: 2
#
#
#             Scale: 200
#             Test: 0
#             Alg: 3
#
#
#             Scale: 200
#             Test: 0
#             Alg: 4
#
#
#             Scale: 200
#             Test: 1
#             Alg: 0
#
#
#             Scale: 200
#             Test: 1
#             Alg: 1
#
#
#             Scale: 200
#             Test: 1
#             Alg: 2
#
#
#             Scale: 200
#             Test: 1
#             Alg: 3
#
#
#             Scale: 200
#             Test: 1
#             Alg: 4
#
#
#             Scale: 200
#             Test: 2
#             Alg: 0
#
#
#             Scale: 200
#             Test: 2
#             Alg: 1
#
#
#             Scale: 200
#             Test: 2
#             Alg: 2
#
#
#             Scale: 200
#             Test: 2
#             Alg: 3
#
#
#             Scale: 200
#             Test: 2
#             Alg: 4
#
#
#             Scale: 200
#             Test: 3
#             Alg: 0
#
#
#             Scale: 200
#             Test: 3
#             Alg: 1
#
#
#             Scale: 200
#             Test: 3
#             Alg: 2
#
#
#             Scale: 200
#             Test: 3
#             Alg: 3
#
#
#             Scale: 200
#             Test: 3
#             Alg: 4
#
#
#             Scale: 200
#             Test: 4
#             Alg: 0
#
#
#             Scale: 200
#             Test: 4
#             Alg: 1
#
#
#             Scale: 200
#             Test: 4
#             Alg: 2
#
#
#             Scale: 200
#             Test: 4
#             Alg: 3
#
#
#             Scale: 200
#             Test: 4
#             Alg: 4
#
#
#             Scale: 200
#             Test: 5
#             Alg: 0
#
#
#             Scale: 200
#             Test: 5
#             Alg: 1
#
#
#             Scale: 200
#             Test: 5
#             Alg: 2
#
#
#             Scale: 200
#             Test: 5
#             Alg: 3
#
#
#             Scale: 200
#             Test: 5
#             Alg: 4
#
#
#             Scale: 200
#             Test: 6
#             Alg: 0
#
#
#             Scale: 200
#             Test: 6
#             Alg: 1
#
#
#             Scale: 200
#             Test: 6
#             Alg: 2
#
#
#             Scale: 200
#             Test: 6
#             Alg: 3
#
#
#             Scale: 200
#             Test: 6
#             Alg: 4
#
#
#             Scale: 200
#             Test: 7
#             Alg: 0
#
#
#             Scale: 200
#             Test: 7
#             Alg: 1
#
#
#             Scale: 200
#             Test: 7
#             Alg: 2
#
#
#             Scale: 200
#             Test: 7
#             Alg: 3
#
#
#             Scale: 200
#             Test: 7
#             Alg: 4
#
#
#             Scale: 200
#             Test: 8
#             Alg: 0
#
#
#             Scale: 200
#             Test: 8
#             Alg: 1
#
#
#             Scale: 200
#             Test: 8
#             Alg: 2
#
#
#             Scale: 200
#             Test: 8
#             Alg: 3
#
#
#             Scale: 200
#             Test: 8
#             Alg: 4
#
#
#             Scale: 200
#             Test: 9
#             Alg: 0
#
#
#             Scale: 200
#             Test: 9
#             Alg: 1
#
#
#             Scale: 200
#             Test: 9
#             Alg: 2
#
#
#             Scale: 200
#             Test: 9
#             Alg: 3
#
#
#             Scale: 200
#             Test: 9
#             Alg: 4
#
#
#             Scale: 400
#             Test: 0
#             Alg: 0
#
#
#             Scale: 400
#             Test: 0
#             Alg: 1
#
#
#             Scale: 400
#             Test: 0
#             Alg: 2
#
#
#             Scale: 400
#             Test: 0
#             Alg: 3
#
#
#             Scale: 400
#             Test: 0
#             Alg: 4
#
#
#             Scale: 400
#             Test: 1
#             Alg: 0
#
#
#             Scale: 400
#             Test: 1
#             Alg: 1
#
#
#             Scale: 400
#             Test: 1
#             Alg: 2
#
#
#             Scale: 400
#             Test: 1
#             Alg: 3
#
#
#             Scale: 400
#             Test: 1
#             Alg: 4
#
#
#             Scale: 400
#             Test: 2
#             Alg: 0
#
#
#             Scale: 400
#             Test: 2
#             Alg: 1
#
#
#             Scale: 400
#             Test: 2
#             Alg: 2
#
#
#             Scale: 400
#             Test: 2
#             Alg: 3
#
#
#             Scale: 400
#             Test: 2
#             Alg: 4
#
#
#             Scale: 400
#             Test: 3
#             Alg: 0
#
#
#             Scale: 400
#             Test: 3
#             Alg: 1
#
#
#             Scale: 400
#             Test: 3
#             Alg: 2
#
#
#             Scale: 400
#             Test: 3
#             Alg: 3
#
#
#             Scale: 400
#             Test: 3
#             Alg: 4
#
#
#             Scale: 400
#             Test: 4
#             Alg: 0
#
#
#             Scale: 400
#             Test: 4
#             Alg: 1
#
#
#             Scale: 400
#             Test: 4
#             Alg: 2
#
#
#             Scale: 400
#             Test: 4
#             Alg: 3
#
#
#             Scale: 400
#             Test: 4
#             Alg: 4
#
#
#             Scale: 400
#             Test: 5
#             Alg: 0
#
#
#             Scale: 400
#             Test: 5
#             Alg: 1
#
#
#             Scale: 400
#             Test: 5
#             Alg: 2
#
#
#             Scale: 400
#             Test: 5
#             Alg: 3
#
#
#             Scale: 400
#             Test: 5
#             Alg: 4
#
#
#             Scale: 400
#             Test: 6
#             Alg: 0
#
#
#             Scale: 400
#             Test: 6
#             Alg: 1
#
#
#             Scale: 400
#             Test: 6
#             Alg: 2
#
#
#             Scale: 400
#             Test: 6
#             Alg: 3
#
#
#             Scale: 400
#             Test: 6
#             Alg: 4
#
#
#             Scale: 400
#             Test: 7
#             Alg: 0
#
#
#             Scale: 400
#             Test: 7
#             Alg: 1
#
#
#             Scale: 400
#             Test: 7
#             Alg: 2
#
#
#             Scale: 400
#             Test: 7
#             Alg: 3
#
#
#             Scale: 400
#             Test: 7
#             Alg: 4
#
#
#             Scale: 400
#             Test: 8
#             Alg: 0
#
#
#             Scale: 400
#             Test: 8
#             Alg: 1
#
#
#             Scale: 400
#             Test: 8
#             Alg: 2
#
#
#             Scale: 400
#             Test: 8
#             Alg: 3
#
#
#             Scale: 400
#             Test: 8
#             Alg: 4
#
#
#             Scale: 400
#             Test: 9
#             Alg: 0
#
#
#             Scale: 400
#             Test: 9
#             Alg: 1
#
#
#             Scale: 400
#             Test: 9
#             Alg: 2
#
#
#             Scale: 400
#             Test: 9
#             Alg: 3
#
#
#             Scale: 400
#             Test: 9
#             Alg: 4
#
#
#             Scale: 600
#             Test: 0
#             Alg: 0
#
#
#             Scale: 600
#             Test: 0
#             Alg: 1
#
#
#             Scale: 600
#             Test: 0
#             Alg: 2
#
#
#             Scale: 600
#             Test: 0
#             Alg: 3
#
#
#             Scale: 600
#             Test: 0
#             Alg: 4
#
#
#             Scale: 600
#             Test: 1
#             Alg: 0
#
#
#             Scale: 600
#             Test: 1
#             Alg: 1
#
#
#             Scale: 600
#             Test: 1
#             Alg: 2
#
#
#             Scale: 600
#             Test: 1
#             Alg: 3
#
#
#             Scale: 600
#             Test: 1
#             Alg: 4
#
#
#             Scale: 600
#             Test: 2
#             Alg: 0
#
#
#             Scale: 600
#             Test: 2
#             Alg: 1
#
#
#             Scale: 600
#             Test: 2
#             Alg: 2
#
#
#             Scale: 600
#             Test: 2
#             Alg: 3
#
#
#             Scale: 600
#             Test: 2
#             Alg: 4
#
#
#             Scale: 600
#             Test: 3
#             Alg: 0
#
#
#             Scale: 600
#             Test: 3
#             Alg: 1
#
#
#             Scale: 600
#             Test: 3
#             Alg: 2
#
#
#             Scale: 600
#             Test: 3
#             Alg: 3
#
#
#             Scale: 600
#             Test: 3
#             Alg: 4
#
#
#             Scale: 600
#             Test: 4
#             Alg: 0
#
#
#             Scale: 600
#             Test: 4
#             Alg: 1
#
#
#             Scale: 600
#             Test: 4
#             Alg: 2
#
#
#             Scale: 600
#             Test: 4
#             Alg: 3
#
#
#             Scale: 600
#             Test: 4
#             Alg: 4
#
#
#             Scale: 600
#             Test: 5
#             Alg: 0
#
#
#             Scale: 600
#             Test: 5
#             Alg: 1
#
#
#             Scale: 600
#             Test: 5
#             Alg: 2
#
#
#             Scale: 600
#             Test: 5
#             Alg: 3
#
#
#             Scale: 600
#             Test: 5
#             Alg: 4
#
#
#             Scale: 600
#             Test: 6
#             Alg: 0
#
#
#             Scale: 600
#             Test: 6
#             Alg: 1
#
#
#             Scale: 600
#             Test: 6
#             Alg: 2
#
#
#             Scale: 600
#             Test: 6
#             Alg: 3
#
#
#             Scale: 600
#             Test: 6
#             Alg: 4
#
#
#             Scale: 600
#             Test: 7
#             Alg: 0
#
#
#             Scale: 600
#             Test: 7
#             Alg: 1
#
#
#             Scale: 600
#             Test: 7
#             Alg: 2
#
#
#             Scale: 600
#             Test: 7
#             Alg: 3
#
#
#             Scale: 600
#             Test: 7
#             Alg: 4
#
#
#             Scale: 600
#             Test: 8
#             Alg: 0
#
#
#             Scale: 600
#             Test: 8
#             Alg: 1
#
#
#             Scale: 600
#             Test: 8
#             Alg: 2
#
#
#             Scale: 600
#             Test: 8
#             Alg: 3
#
#
#             Scale: 600
#             Test: 8
#             Alg: 4
#
#
#             Scale: 600
#             Test: 9
#             Alg: 0
#
#
#             Scale: 600
#             Test: 9
#             Alg: 1
#
#
#             Scale: 600
#             Test: 9
#             Alg: 2
#
#
#             Scale: 600
#             Test: 9
#             Alg: 3
#
#
#             Scale: 600
#             Test: 9
#             Alg: 4
#
#
#             Scale: 800
#             Test: 0
#             Alg: 0
#
#
#             Scale: 800
#             Test: 0
#             Alg: 1
#
#
#             Scale: 800
#             Test: 0
#             Alg: 2
#
#
#             Scale: 800
#             Test: 0
#             Alg: 3
#
#
#             Scale: 800
#             Test: 0
#             Alg: 4
#
#
#             Scale: 800
#             Test: 1
#             Alg: 0
#
#
#             Scale: 800
#             Test: 1
#             Alg: 1
#
#
#             Scale: 800
#             Test: 1
#             Alg: 2
#
#
#             Scale: 800
#             Test: 1
#             Alg: 3
#
#
#             Scale: 800
#             Test: 1
#             Alg: 4
#
#
#             Scale: 800
#             Test: 2
#             Alg: 0
#
#
#             Scale: 800
#             Test: 2
#             Alg: 1
#
#
#             Scale: 800
#             Test: 2
#             Alg: 2
#
#
#             Scale: 800
#             Test: 2
#             Alg: 3
#
#
#             Scale: 800
#             Test: 2
#             Alg: 4
#
#
#             Scale: 800
#             Test: 3
#             Alg: 0
#
#
#             Scale: 800
#             Test: 3
#             Alg: 1
#
#
#             Scale: 800
#             Test: 3
#             Alg: 2
#
#
#             Scale: 800
#             Test: 3
#             Alg: 3
#
#
#             Scale: 800
#             Test: 3
#             Alg: 4
#
#
#             Scale: 800
#             Test: 4
#             Alg: 0
#
#
#             Scale: 800
#             Test: 4
#             Alg: 1
#
#
#             Scale: 800
#             Test: 4
#             Alg: 2
#
#
#             Scale: 800
#             Test: 4
#             Alg: 3
#
#
#             Scale: 800
#             Test: 4
#             Alg: 4
#
#
#             Scale: 800
#             Test: 5
#             Alg: 0
#
#
#             Scale: 800
#             Test: 5
#             Alg: 1
#
#
#             Scale: 800
#             Test: 5
#             Alg: 2
#
#
#             Scale: 800
#             Test: 5
#             Alg: 3
#
#
#             Scale: 800
#             Test: 5
#             Alg: 4
#
#
#             Scale: 800
#             Test: 6
#             Alg: 0
#
#
#             Scale: 800
#             Test: 6
#             Alg: 1
#
#
#             Scale: 800
#             Test: 6
#             Alg: 2
#
#
#             Scale: 800
#             Test: 6
#             Alg: 3
#
#
#             Scale: 800
#             Test: 6
#             Alg: 4
#
#
#             Scale: 800
#             Test: 7
#             Alg: 0
#
#
#             Scale: 800
#             Test: 7
#             Alg: 1
#
#
#             Scale: 800
#             Test: 7
#             Alg: 2
#
#
#             Scale: 800
#             Test: 7
#             Alg: 3
#
#
#             Scale: 800
#             Test: 7
#             Alg: 4
#
#
#             Scale: 800
#             Test: 8
#             Alg: 0
#
#
#             Scale: 800
#             Test: 8
#             Alg: 1
#
#
#             Scale: 800
#             Test: 8
#             Alg: 2
#
#
#             Scale: 800
#             Test: 8
#             Alg: 3
#
#
#             Scale: 800
#             Test: 8
#             Alg: 4
#
#
#             Scale: 800
#             Test: 9
#             Alg: 0
#
#
#             Scale: 800
#             Test: 9
#             Alg: 1
#
#
#             Scale: 800
#             Test: 9
#             Alg: 2
#
#
#             Scale: 800
#             Test: 9
#             Alg: 3
#
#
#             Scale: 800
#             Test: 9
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 0
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 0
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 0
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 0
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 0
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 1
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 1
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 1
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 1
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 1
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 2
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 2
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 2
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 2
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 2
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 3
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 3
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 3
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 3
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 3
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 4
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 4
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 4
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 4
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 4
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 5
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 5
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 5
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 5
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 5
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 6
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 6
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 6
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 6
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 6
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 7
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 7
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 7
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 7
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 7
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 8
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 8
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 8
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 8
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 8
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 9
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 9
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 9
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 9
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 9
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 0
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 0
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 0
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 0
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 0
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 1
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 1
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 1
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 1
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 1
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 2
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 2
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 2
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 2
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 2
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 3
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 3
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 3
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 3
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 3
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 4
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 4
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 4
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 4
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 4
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 5
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 5
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 5
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 5
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 5
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 6
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 6
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 6
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 6
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 6
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 7
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 7
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 7
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 7
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 7
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 8
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 8
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 8
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 8
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 8
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 9
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 9
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 9
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 9
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 9
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 0
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 0
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 0
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 0
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 0
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 1
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 1
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 1
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 1
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 1
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 2
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 2
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 2
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 2
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 2
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 3
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 3
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 3
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 3
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 3
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 4
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 4
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 4
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 4
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 4
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 5
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 5
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 5
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 5
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 5
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 6
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 6
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 6
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 6
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 6
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 7
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 7
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 7
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 7
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 7
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 8
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 8
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 8
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 8
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 8
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 9
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 9
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 9
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 9
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 9
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 0
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 0
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 0
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 0
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 0
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 1
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 1
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 1
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 1
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 1
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 2
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 2
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 2
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 2
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 2
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 3
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 3
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 3
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 3
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 3
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 4
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 4
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 4
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 4
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 4
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 5
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 5
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 5
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 5
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 5
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 6
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 6
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 6
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 6
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 6
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 7
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 7
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 7
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 7
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 7
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 8
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 8
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 8
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 8
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 8
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 9
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 9
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 9
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 9
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 9
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 0
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 0
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 0
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 0
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 0
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 1
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 1
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 1
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 1
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 1
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 2
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 2
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 2
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 2
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 2
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 3
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 3
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 3
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 3
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 3
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 4
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 4
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 4
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 4
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 4
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 5
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 5
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 5
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 5
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 5
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 6
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 6
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 6
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 6
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 6
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 7
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 7
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 7
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 7
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 7
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 8
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 8
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 8
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 8
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 8
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 9
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 9
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 9
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 9
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 9
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 0
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 0
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 0
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 0
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 0
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 1
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 1
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 1
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 1
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 1
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 2
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 2
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 2
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 2
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 2
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 3
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 3
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 3
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 3
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 3
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 4
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 4
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 4
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 4
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 4
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 5
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 5
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 5
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 5
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 5
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 6
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 6
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 6
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 6
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 6
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 7
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 7
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 7
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 7
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 7
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 8
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 8
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 8
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 8
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 8
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 9
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 9
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 9
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 9
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 9
#             Alg: 4

# %%
# Get the record and plot the result
avgTimeArr=np.zeros((5,10))
for algId in range(5):
    for scaleId in range(10):
        avgTimeArr[algId,scaleId] = timeArr[scaleId,:,algId].mean()
    plt.plot(scaleLst, avgTimeArr[algId,:])

with open('time.csv','x',encoding='utf-8') as f:
    time_csv=csv.writer(f)
    time_csv.writerows(avgTimeArr)






# scale=2000
# # Initialize random array
# fD = [random.randint(-1e5,1e5) for _ in range(scale)]
# # Initialize Alg Class with iNum and fD
# MycAlg = cAlg(scale,fD)


# MycAlg.Alg_Sort1()
# print(MycAlg.fD)
# print(MycAlg.fD==sorted(MycAlg.fD))
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# d:\Codes\Python_Homework\Algorithm\Lab\sortMain.py in line 9
#       <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=56'>57</a>         avgTimeArr[algId,scaleId] = timeArr[scaleId,:,algId].mean()
#       <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=57'>58</a>     plt.plot(scaleLst, avgTimeArr[algId,:])
# ----> <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=59'>60</a> with open('time.csv','x',encoding='utf-8') as f:
#      <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=60'>61</a>     time_csv=csv.writer(f)
#      <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=61'>62</a>     time_csv.writerows(avgTimeArr)
#
# File c:\Users\Redmibook_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=274'>275</a> if file in {0, 1, 2}:
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=275'>276</a>     raise ValueError(
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=276'>277</a>         f"IPython won't let you open fd={file} by default "
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=277'>278</a>         "as it is likely to crash IPython. If you know what you are doing, "
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=278'>279</a>         "you can use builtins' open."
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=279'>280</a>     )
# --> <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=281'>282</a> return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'time.csv'

# %%
# Get the record and plot the result
avgTimeArr=np.zeros((5,10))
for algId in range(5):
    for scaleId in range(10):
        avgTimeArr[algId,scaleId] = timeArr[scaleId,:,algId].mean()
    plt.plot(scaleLst, avgTimeArr[algId,:])

with open('time.csv','W',encoding='utf-8') as f:
    time_csv=csv.writer(f)
    time_csv.writerows(avgTimeArr)






# scale=2000
# # Initialize random array
# fD = [random.randint(-1e5,1e5) for _ in range(scale)]
# # Initialize Alg Class with iNum and fD
# MycAlg = cAlg(scale,fD)


# MycAlg.Alg_Sort1()
# print(MycAlg.fD)
# print(MycAlg.fD==sorted(MycAlg.fD))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Codes\Python_Homework\Algorithm\Lab\sortMain.py in line 9
#       <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=56'>57</a>         avgTimeArr[algId,scaleId] = timeArr[scaleId,:,algId].mean()
#       <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=57'>58</a>     plt.plot(scaleLst, avgTimeArr[algId,:])
# ----> <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=59'>60</a> with open('time.csv','W',encoding='utf-8') as f:
#      <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=60'>61</a>     time_csv=csv.writer(f)
#      <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=61'>62</a>     time_csv.writerows(avgTimeArr)
#
# File c:\Users\Redmibook_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=274'>275</a> if file in {0, 1, 2}:
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=275'>276</a>     raise ValueError(
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=276'>277</a>         f"IPython won't let you open fd={file} by default "
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=277'>278</a>         "as it is likely to crash IPython. If you know what you are doing, "
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=278'>279</a>         "you can use builtins' open."
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=279'>280</a>     )
# --> <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=281'>282</a> return io_open(file, *args, **kwargs)
#
# ValueError: invalid mode: 'W'

# %%
# Get the record and plot the result
avgTimeArr=np.zeros((5,10))
for algId in range(5):
    for scaleId in range(10):
        avgTimeArr[algId,scaleId] = timeArr[scaleId,:,algId].mean()
    plt.plot(scaleLst, avgTimeArr[algId,:])

with open('time.csv','W',encoding='utf-8') as f:
    time_csv=csv.writer(f)
    time_csv.writerows(avgTimeArr)






# scale=2000
# # Initialize random array
# fD = [random.randint(-1e5,1e5) for _ in range(scale)]
# # Initialize Alg Class with iNum and fD
# MycAlg = cAlg(scale,fD)


# MycAlg.Alg_Sort1()
# print(MycAlg.fD)
# print(MycAlg.fD==sorted(MycAlg.fD))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Codes\Python_Homework\Algorithm\Lab\sortMain.py in line 9
#       <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=56'>57</a>         avgTimeArr[algId,scaleId] = timeArr[scaleId,:,algId].mean()
#       <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=57'>58</a>     plt.plot(scaleLst, avgTimeArr[algId,:])
# ----> <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=59'>60</a> with open('time.csv','W',encoding='utf-8') as f:
#      <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=60'>61</a>     time_csv=csv.writer(f)
#      <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=61'>62</a>     time_csv.writerows(avgTimeArr)
#
# File c:\Users\Redmibook_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=274'>275</a> if file in {0, 1, 2}:
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=275'>276</a>     raise ValueError(
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=276'>277</a>         f"IPython won't let you open fd={file} by default "
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=277'>278</a>         "as it is likely to crash IPython. If you know what you are doing, "
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=278'>279</a>         "you can use builtins' open."
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=279'>280</a>     )
# --> <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=281'>282</a> return io_open(file, *args, **kwargs)
#
# ValueError: invalid mode: 'W'

# %%
# Get the record and plot the result
avgTimeArr=np.zeros((5,10))
for algId in range(5):
    for scaleId in range(10):
        avgTimeArr[algId,scaleId] = timeArr[scaleId,:,algId].mean()
    plt.plot(scaleLst, avgTimeArr[algId,:])

with open('time.csv','w',encoding='utf-8') as f:
    time_csv=csv.writer(f)
    time_csv.writerows(avgTimeArr)






# scale=2000
# # Initialize random array
# fD = [random.randint(-1e5,1e5) for _ in range(scale)]
# # Initialize Alg Class with iNum and fD
# MycAlg = cAlg(scale,fD)


# MycAlg.Alg_Sort1()
# print(MycAlg.fD)
# print(MycAlg.fD==sorted(MycAlg.fD))
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# d:\Codes\Python_Homework\Algorithm\Lab\sortMain.py in line 9
#       <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=56'>57</a>         avgTimeArr[algId,scaleId] = timeArr[scaleId,:,algId].mean()
#       <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=57'>58</a>     plt.plot(scaleLst, avgTimeArr[algId,:])
# ----> <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=59'>60</a> with open('time.csv','w',encoding='utf-8') as f:
#      <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=60'>61</a>     time_csv=csv.writer(f)
#      <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=61'>62</a>     time_csv.writerows(avgTimeArr)
#
# File c:\Users\Redmibook_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=274'>275</a> if file in {0, 1, 2}:
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=275'>276</a>     raise ValueError(
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=276'>277</a>         f"IPython won't let you open fd={file} by default "
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=277'>278</a>         "as it is likely to crash IPython. If you know what you are doing, "
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=278'>279</a>         "you can use builtins' open."
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=279'>280</a>     )
# --> <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=281'>282</a> return io_open(file, *args, **kwargs)
#
# PermissionError: [Errno 13] Permission denied: 'time.csv'

# %%
# Get the record and plot the result
avgTimeArr=np.zeros((5,10))
for algId in range(5):
    for scaleId in range(10):
        avgTimeArr[algId,scaleId] = timeArr[scaleId,:,algId].mean()
    plt.plot(scaleLst, avgTimeArr[algId,:])

with open('time.csv','w',encoding='utf-8') as f:
    time_csv=csv.writer(f)
    time_csv.writerows(avgTimeArr)






# scale=2000
# # Initialize random array
# fD = [random.randint(-1e5,1e5) for _ in range(scale)]
# # Initialize Alg Class with iNum and fD
# MycAlg = cAlg(scale,fD)


# MycAlg.Alg_Sort1()
# print(MycAlg.fD)
# print(MycAlg.fD==sorted(MycAlg.fD))

# %%
# timeArr is for counting and statics
timeArr = np.zeros((10,10,5))
scaleLst= [iNum for iNum in range(200,2001,200)]
MycAlg = cAlg(0,[])
sortingFuncLst = [
        MycAlg.Alg_Sort1,
        MycAlg.Alg_Sort2,
        MycAlg.Alg_Sort3,
        MycAlg.Alg_Sort4,
        MycAlg.Alg_Sort5,
    ]


for scaleId, scale in enumerate(scaleLst):

    # For each scale, program will carry out 10 tests 
    # to find the average performance 
    for testId in range(10):

        # Initialize random array
        fD = [random.randint(-1e5,1e5) for _ in range(scale)]

        # For each test, program will run the 5 types of
        # sorting algorithm to distinc the differences
        for AlgId in range(5):

            # Initialize Alg Class with iNum and fD
            MycAlg.set_fD(scale,fD)

            start_time = time.time()
            sortingFuncLst[AlgId]()
            end_time = time.time()

            # Take record of the consumption time
            timeArr[scaleId,testId,AlgId] = end_time - start_time
            
            print(f'''
            Scale: {scale}
            Test: {testId}
            Alg: {AlgId}
            ''')
# Out:
#             Scale: 200
#             Test: 0
#             Alg: 0
#
#
#             Scale: 200
#             Test: 0
#             Alg: 1
#
#
#             Scale: 200
#             Test: 0
#             Alg: 2
#
#
#             Scale: 200
#             Test: 0
#             Alg: 3
#
#
#             Scale: 200
#             Test: 0
#             Alg: 4
#
#
#             Scale: 200
#             Test: 1
#             Alg: 0
#
#
#             Scale: 200
#             Test: 1
#             Alg: 1
#
#
#             Scale: 200
#             Test: 1
#             Alg: 2
#
#
#             Scale: 200
#             Test: 1
#             Alg: 3
#
#
#             Scale: 200
#             Test: 1
#             Alg: 4
#
#
#             Scale: 200
#             Test: 2
#             Alg: 0
#
#
#             Scale: 200
#             Test: 2
#             Alg: 1
#
#
#             Scale: 200
#             Test: 2
#             Alg: 2
#
#
#             Scale: 200
#             Test: 2
#             Alg: 3
#
#
#             Scale: 200
#             Test: 2
#             Alg: 4
#
#
#             Scale: 200
#             Test: 3
#             Alg: 0
#
#
#             Scale: 200
#             Test: 3
#             Alg: 1
#
#
#             Scale: 200
#             Test: 3
#             Alg: 2
#
#
#             Scale: 200
#             Test: 3
#             Alg: 3
#
#
#             Scale: 200
#             Test: 3
#             Alg: 4
#
#
#             Scale: 200
#             Test: 4
#             Alg: 0
#
#
#             Scale: 200
#             Test: 4
#             Alg: 1
#
#
#             Scale: 200
#             Test: 4
#             Alg: 2
#
#
#             Scale: 200
#             Test: 4
#             Alg: 3
#
#
#             Scale: 200
#             Test: 4
#             Alg: 4
#
#
#             Scale: 200
#             Test: 5
#             Alg: 0
#
#
#             Scale: 200
#             Test: 5
#             Alg: 1
#
#
#             Scale: 200
#             Test: 5
#             Alg: 2
#
#
#             Scale: 200
#             Test: 5
#             Alg: 3
#
#
#             Scale: 200
#             Test: 5
#             Alg: 4
#
#
#             Scale: 200
#             Test: 6
#             Alg: 0
#
#
#             Scale: 200
#             Test: 6
#             Alg: 1
#
#
#             Scale: 200
#             Test: 6
#             Alg: 2
#
#
#             Scale: 200
#             Test: 6
#             Alg: 3
#
#
#             Scale: 200
#             Test: 6
#             Alg: 4
#
#
#             Scale: 200
#             Test: 7
#             Alg: 0
#
#
#             Scale: 200
#             Test: 7
#             Alg: 1
#
#
#             Scale: 200
#             Test: 7
#             Alg: 2
#
#
#             Scale: 200
#             Test: 7
#             Alg: 3
#
#
#             Scale: 200
#             Test: 7
#             Alg: 4
#
#
#             Scale: 200
#             Test: 8
#             Alg: 0
#
#
#             Scale: 200
#             Test: 8
#             Alg: 1
#
#
#             Scale: 200
#             Test: 8
#             Alg: 2
#
#
#             Scale: 200
#             Test: 8
#             Alg: 3
#
#
#             Scale: 200
#             Test: 8
#             Alg: 4
#
#
#             Scale: 200
#             Test: 9
#             Alg: 0
#
#
#             Scale: 200
#             Test: 9
#             Alg: 1
#
#
#             Scale: 200
#             Test: 9
#             Alg: 2
#
#
#             Scale: 200
#             Test: 9
#             Alg: 3
#
#
#             Scale: 200
#             Test: 9
#             Alg: 4
#
#
#             Scale: 400
#             Test: 0
#             Alg: 0
#
#
#             Scale: 400
#             Test: 0
#             Alg: 1
#
#
#             Scale: 400
#             Test: 0
#             Alg: 2
#
#
#             Scale: 400
#             Test: 0
#             Alg: 3
#
#
#             Scale: 400
#             Test: 0
#             Alg: 4
#
#
#             Scale: 400
#             Test: 1
#             Alg: 0
#
#
#             Scale: 400
#             Test: 1
#             Alg: 1
#
#
#             Scale: 400
#             Test: 1
#             Alg: 2
#
#
#             Scale: 400
#             Test: 1
#             Alg: 3
#
#
#             Scale: 400
#             Test: 1
#             Alg: 4
#
#
#             Scale: 400
#             Test: 2
#             Alg: 0
#
#
#             Scale: 400
#             Test: 2
#             Alg: 1
#
#
#             Scale: 400
#             Test: 2
#             Alg: 2
#
#
#             Scale: 400
#             Test: 2
#             Alg: 3
#
#
#             Scale: 400
#             Test: 2
#             Alg: 4
#
#
#             Scale: 400
#             Test: 3
#             Alg: 0
#
#
#             Scale: 400
#             Test: 3
#             Alg: 1
#
#
#             Scale: 400
#             Test: 3
#             Alg: 2
#
#
#             Scale: 400
#             Test: 3
#             Alg: 3
#
#
#             Scale: 400
#             Test: 3
#             Alg: 4
#
#
#             Scale: 400
#             Test: 4
#             Alg: 0
#
#
#             Scale: 400
#             Test: 4
#             Alg: 1
#
#
#             Scale: 400
#             Test: 4
#             Alg: 2
#
#
#             Scale: 400
#             Test: 4
#             Alg: 3
#
#
#             Scale: 400
#             Test: 4
#             Alg: 4
#
#
#             Scale: 400
#             Test: 5
#             Alg: 0
#
#
#             Scale: 400
#             Test: 5
#             Alg: 1
#
#
#             Scale: 400
#             Test: 5
#             Alg: 2
#
#
#             Scale: 400
#             Test: 5
#             Alg: 3
#
#
#             Scale: 400
#             Test: 5
#             Alg: 4
#
#
#             Scale: 400
#             Test: 6
#             Alg: 0
#
#
#             Scale: 400
#             Test: 6
#             Alg: 1
#
#
#             Scale: 400
#             Test: 6
#             Alg: 2
#
#
#             Scale: 400
#             Test: 6
#             Alg: 3
#
#
#             Scale: 400
#             Test: 6
#             Alg: 4
#
#
#             Scale: 400
#             Test: 7
#             Alg: 0
#
#
#             Scale: 400
#             Test: 7
#             Alg: 1
#
#
#             Scale: 400
#             Test: 7
#             Alg: 2
#
#
#             Scale: 400
#             Test: 7
#             Alg: 3
#
#
#             Scale: 400
#             Test: 7
#             Alg: 4
#
#
#             Scale: 400
#             Test: 8
#             Alg: 0
#
#
#             Scale: 400
#             Test: 8
#             Alg: 1
#
#
#             Scale: 400
#             Test: 8
#             Alg: 2
#
#
#             Scale: 400
#             Test: 8
#             Alg: 3
#
#
#             Scale: 400
#             Test: 8
#             Alg: 4
#
#
#             Scale: 400
#             Test: 9
#             Alg: 0
#
#
#             Scale: 400
#             Test: 9
#             Alg: 1
#
#
#             Scale: 400
#             Test: 9
#             Alg: 2
#
#
#             Scale: 400
#             Test: 9
#             Alg: 3
#
#
#             Scale: 400
#             Test: 9
#             Alg: 4
#
#
#             Scale: 600
#             Test: 0
#             Alg: 0
#
#
#             Scale: 600
#             Test: 0
#             Alg: 1
#
#
#             Scale: 600
#             Test: 0
#             Alg: 2
#
#
#             Scale: 600
#             Test: 0
#             Alg: 3
#
#
#             Scale: 600
#             Test: 0
#             Alg: 4
#
#
#             Scale: 600
#             Test: 1
#             Alg: 0
#
#
#             Scale: 600
#             Test: 1
#             Alg: 1
#
#
#             Scale: 600
#             Test: 1
#             Alg: 2
#
#
#             Scale: 600
#             Test: 1
#             Alg: 3
#
#
#             Scale: 600
#             Test: 1
#             Alg: 4
#
#
#             Scale: 600
#             Test: 2
#             Alg: 0
#
#
#             Scale: 600
#             Test: 2
#             Alg: 1
#
#
#             Scale: 600
#             Test: 2
#             Alg: 2
#
#
#             Scale: 600
#             Test: 2
#             Alg: 3
#
#
#             Scale: 600
#             Test: 2
#             Alg: 4
#
#
#             Scale: 600
#             Test: 3
#             Alg: 0
#
#
#             Scale: 600
#             Test: 3
#             Alg: 1
#
#
#             Scale: 600
#             Test: 3
#             Alg: 2
#
#
#             Scale: 600
#             Test: 3
#             Alg: 3
#
#
#             Scale: 600
#             Test: 3
#             Alg: 4
#
#
#             Scale: 600
#             Test: 4
#             Alg: 0
#
#
#             Scale: 600
#             Test: 4
#             Alg: 1
#
#
#             Scale: 600
#             Test: 4
#             Alg: 2
#
#
#             Scale: 600
#             Test: 4
#             Alg: 3
#
#
#             Scale: 600
#             Test: 4
#             Alg: 4
#
#
#             Scale: 600
#             Test: 5
#             Alg: 0
#
#
#             Scale: 600
#             Test: 5
#             Alg: 1
#
#
#             Scale: 600
#             Test: 5
#             Alg: 2
#
#
#             Scale: 600
#             Test: 5
#             Alg: 3
#
#
#             Scale: 600
#             Test: 5
#             Alg: 4
#
#
#             Scale: 600
#             Test: 6
#             Alg: 0
#
#
#             Scale: 600
#             Test: 6
#             Alg: 1
#
#
#             Scale: 600
#             Test: 6
#             Alg: 2
#
#
#             Scale: 600
#             Test: 6
#             Alg: 3
#
#
#             Scale: 600
#             Test: 6
#             Alg: 4
#
#
#             Scale: 600
#             Test: 7
#             Alg: 0
#
#
#             Scale: 600
#             Test: 7
#             Alg: 1
#
#
#             Scale: 600
#             Test: 7
#             Alg: 2
#
#
#             Scale: 600
#             Test: 7
#             Alg: 3
#
#
#             Scale: 600
#             Test: 7
#             Alg: 4
#
#
#             Scale: 600
#             Test: 8
#             Alg: 0
#
#
#             Scale: 600
#             Test: 8
#             Alg: 1
#
#
#             Scale: 600
#             Test: 8
#             Alg: 2
#
#
#             Scale: 600
#             Test: 8
#             Alg: 3
#
#
#             Scale: 600
#             Test: 8
#             Alg: 4
#
#
#             Scale: 600
#             Test: 9
#             Alg: 0
#
#
#             Scale: 600
#             Test: 9
#             Alg: 1
#
#
#             Scale: 600
#             Test: 9
#             Alg: 2
#
#
#             Scale: 600
#             Test: 9
#             Alg: 3
#
#
#             Scale: 600
#             Test: 9
#             Alg: 4
#
#
#             Scale: 800
#             Test: 0
#             Alg: 0
#
#
#             Scale: 800
#             Test: 0
#             Alg: 1
#
#
#             Scale: 800
#             Test: 0
#             Alg: 2
#
#
#             Scale: 800
#             Test: 0
#             Alg: 3
#
#
#             Scale: 800
#             Test: 0
#             Alg: 4
#
#
#             Scale: 800
#             Test: 1
#             Alg: 0
#
#
#             Scale: 800
#             Test: 1
#             Alg: 1
#
#
#             Scale: 800
#             Test: 1
#             Alg: 2
#
#
#             Scale: 800
#             Test: 1
#             Alg: 3
#
#
#             Scale: 800
#             Test: 1
#             Alg: 4
#
#
#             Scale: 800
#             Test: 2
#             Alg: 0
#
#
#             Scale: 800
#             Test: 2
#             Alg: 1
#
#
#             Scale: 800
#             Test: 2
#             Alg: 2
#
#
#             Scale: 800
#             Test: 2
#             Alg: 3
#
#
#             Scale: 800
#             Test: 2
#             Alg: 4
#
#
#             Scale: 800
#             Test: 3
#             Alg: 0
#
#
#             Scale: 800
#             Test: 3
#             Alg: 1
#
#
#             Scale: 800
#             Test: 3
#             Alg: 2
#
#
#             Scale: 800
#             Test: 3
#             Alg: 3
#
#
#             Scale: 800
#             Test: 3
#             Alg: 4
#
#
#             Scale: 800
#             Test: 4
#             Alg: 0
#
#
#             Scale: 800
#             Test: 4
#             Alg: 1
#
#
#             Scale: 800
#             Test: 4
#             Alg: 2
#
#
#             Scale: 800
#             Test: 4
#             Alg: 3
#
#
#             Scale: 800
#             Test: 4
#             Alg: 4
#
#
#             Scale: 800
#             Test: 5
#             Alg: 0
#
#
#             Scale: 800
#             Test: 5
#             Alg: 1
#
#
#             Scale: 800
#             Test: 5
#             Alg: 2
#
#
#             Scale: 800
#             Test: 5
#             Alg: 3
#
#
#             Scale: 800
#             Test: 5
#             Alg: 4
#
#
#             Scale: 800
#             Test: 6
#             Alg: 0
#
#
#             Scale: 800
#             Test: 6
#             Alg: 1
#
#
#             Scale: 800
#             Test: 6
#             Alg: 2
#
#
#             Scale: 800
#             Test: 6
#             Alg: 3
#
#
#             Scale: 800
#             Test: 6
#             Alg: 4
#
#
#             Scale: 800
#             Test: 7
#             Alg: 0
#
#
#             Scale: 800
#             Test: 7
#             Alg: 1
#
#
#             Scale: 800
#             Test: 7
#             Alg: 2
#
#
#             Scale: 800
#             Test: 7
#             Alg: 3
#
#
#             Scale: 800
#             Test: 7
#             Alg: 4
#
#
#             Scale: 800
#             Test: 8
#             Alg: 0
#
#
#             Scale: 800
#             Test: 8
#             Alg: 1
#
#
#             Scale: 800
#             Test: 8
#             Alg: 2
#
#
#             Scale: 800
#             Test: 8
#             Alg: 3
#
#
#             Scale: 800
#             Test: 8
#             Alg: 4
#
#
#             Scale: 800
#             Test: 9
#             Alg: 0
#
#
#             Scale: 800
#             Test: 9
#             Alg: 1
#
#
#             Scale: 800
#             Test: 9
#             Alg: 2
#
#
#             Scale: 800
#             Test: 9
#             Alg: 3
#
#
#             Scale: 800
#             Test: 9
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 0
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 0
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 0
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 0
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 0
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 1
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 1
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 1
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 1
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 1
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 2
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 2
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 2
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 2
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 2
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 3
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 3
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 3
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 3
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 3
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 4
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 4
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 4
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 4
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 4
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 5
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 5
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 5
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 5
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 5
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 6
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 6
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 6
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 6
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 6
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 7
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 7
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 7
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 7
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 7
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 8
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 8
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 8
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 8
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 8
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 9
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 9
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 9
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 9
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 9
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 0
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 0
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 0
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 0
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 0
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 1
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 1
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 1
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 1
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 1
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 2
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 2
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 2
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 2
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 2
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 3
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 3
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 3
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 3
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 3
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 4
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 4
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 4
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 4
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 4
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 5
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 5
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 5
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 5
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 5
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 6
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 6
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 6
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 6
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 6
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 7
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 7
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 7
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 7
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 7
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 8
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 8
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 8
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 8
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 8
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 9
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 9
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 9
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 9
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 9
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 0
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 0
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 0
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 0
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 0
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 1
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 1
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 1
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 1
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 1
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 2
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 2
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 2
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 2
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 2
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 3
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 3
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 3
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 3
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 3
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 4
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 4
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 4
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 4
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 4
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 5
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 5
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 5
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 5
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 5
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 6
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 6
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 6
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 6
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 6
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 7
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 7
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 7
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 7
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 7
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 8
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 8
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 8
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 8
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 8
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 9
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 9
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 9
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 9
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 9
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 0
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 0
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 0
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 0
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 0
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 1
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 1
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 1
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 1
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 1
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 2
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 2
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 2
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 2
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 2
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 3
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 3
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 3
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 3
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 3
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 4
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 4
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 4
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 4
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 4
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 5
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 5
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 5
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 5
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 5
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 6
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 6
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 6
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 6
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 6
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 7
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 7
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 7
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 7
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 7
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 8
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 8
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 8
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 8
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 8
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 9
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 9
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 9
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 9
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 9
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 0
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 0
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 0
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 0
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 0
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 1
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 1
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 1
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 1
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 1
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 2
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 2
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 2
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 2
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 2
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 3
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 3
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 3
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 3
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 3
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 4
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 4
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 4
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 4
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 4
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 5
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 5
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 5
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 5
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 5
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 6
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 6
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 6
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 6
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 6
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 7
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 7
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 7
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 7
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 7
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 8
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 8
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 8
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 8
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 8
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 9
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 9
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 9
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 9
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 9
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 0
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 0
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 0
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 0
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 0
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 1
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 1
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 1
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 1
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 1
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 2
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 2
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 2
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 2
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 2
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 3
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 3
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 3
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 3
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 3
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 4
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 4
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 4
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 4
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 4
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 5
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 5
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 5
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 5
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 5
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 6
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 6
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 6
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 6
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 6
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 7
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 7
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 7
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 7
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 7
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 8
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 8
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 8
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 8
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 8
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 9
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 9
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 9
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 9
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 9
#             Alg: 4

# %%
# Get the record and plot the result
avgTimeArr=np.zeros((5,10))
for algId in range(5):
    for scaleId in range(10):
        avgTimeArr[algId,scaleId] = timeArr[scaleId,:,algId].mean()
    plt.plot(scaleLst, avgTimeArr[algId,:])

with open('time.csv','w',encoding='utf-8') as f:
    time_csv=csv.writer(f)
    time_csv.writerows(avgTimeArr)






# scale=2000
# # Initialize random array
# fD = [random.randint(-1e5,1e5) for _ in range(scale)]
# # Initialize Alg Class with iNum and fD
# MycAlg = cAlg(scale,fD)


# MycAlg.Alg_Sort1()
# print(MycAlg.fD)
# print(MycAlg.fD==sorted(MycAlg.fD))
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# d:\Codes\Python_Homework\Algorithm\Lab\sortMain.py in line 9
#       <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=56'>57</a>         avgTimeArr[algId,scaleId] = timeArr[scaleId,:,algId].mean()
#       <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=57'>58</a>     plt.plot(scaleLst, avgTimeArr[algId,:])
# ----> <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=59'>60</a> with open('time.csv','w',encoding='utf-8') as f:
#      <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=60'>61</a>     time_csv=csv.writer(f)
#      <a href='file:///d%3A/Codes/Python_Homework/Algorithm/Lab/sortMain.py?line=61'>62</a>     time_csv.writerows(avgTimeArr)
#
# File c:\Users\Redmibook_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=274'>275</a> if file in {0, 1, 2}:
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=275'>276</a>     raise ValueError(
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=276'>277</a>         f"IPython won't let you open fd={file} by default "
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=277'>278</a>         "as it is likely to crash IPython. If you know what you are doing, "
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=278'>279</a>         "you can use builtins' open."
#     <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=279'>280</a>     )
# --> <a href='file:///c%3A/Users/Redmibook_PC/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=281'>282</a> return io_open(file, *args, **kwargs)
#
# PermissionError: [Errno 13] Permission denied: 'time.csv'

# %%
# Get the record and plot the result
avgTimeArr=np.zeros((5,10))
for algId in range(5):
    for scaleId in range(10):
        avgTimeArr[algId,scaleId] = timeArr[scaleId,:,algId].mean()
    plt.plot(scaleLst, avgTimeArr[algId,:])

with open('time.csv','w',encoding='utf-8') as f:
    time_csv=csv.writer(f)
    time_csv.writerows(avgTimeArr)






# scale=2000
# # Initialize random array
# fD = [random.randint(-1e5,1e5) for _ in range(scale)]
# # Initialize Alg Class with iNum and fD
# MycAlg = cAlg(scale,fD)


# MycAlg.Alg_Sort1()
# print(MycAlg.fD)
# print(MycAlg.fD==sorted(MycAlg.fD))

# %%
# timeArr is for counting and statics
timeArr = np.zeros((10,10,5))
scaleLst= [iNum for iNum in range(200,2001,200)]
MycAlg = cAlg(0,[])
sortingFuncLst = [
        MycAlg.Alg_Sort1,
        MycAlg.Alg_Sort2,
        MycAlg.Alg_Sort3,
        MycAlg.Alg_Sort4,
        MycAlg.Alg_Sort5,
    ]


for scaleId, scale in enumerate(scaleLst):

    # For each scale, program will carry out 10 tests 
    # to find the average performance 
    for testId in range(10):

        # Initialize random array
        # fD = [random.randint(-1e5,1e5) for _ in range(scale)]

        # For each test, program will run the 5 types of
        # sorting algorithm to distinc the differences
        for AlgId in range(5):

            # Initialize Alg Class with iNum and fD
            fD = [random.randint(-1e5,1e5) for _ in range(scale)]
            MycAlg.set_fD(scale,fD)

            start_time = time.time()
            sortingFuncLst[AlgId]()
            end_time = time.time()

            # Take record of the consumption time
            timeArr[scaleId,testId,AlgId] = end_time - start_time
            
            print(f'''
            Scale: {scale}
            Test: {testId}
            Alg: {AlgId}
            ''')
# Out:
#             Scale: 200
#             Test: 0
#             Alg: 0
#
#
#             Scale: 200
#             Test: 0
#             Alg: 1
#
#
#             Scale: 200
#             Test: 0
#             Alg: 2
#
#
#             Scale: 200
#             Test: 0
#             Alg: 3
#
#
#             Scale: 200
#             Test: 0
#             Alg: 4
#
#
#             Scale: 200
#             Test: 1
#             Alg: 0
#
#
#             Scale: 200
#             Test: 1
#             Alg: 1
#
#
#             Scale: 200
#             Test: 1
#             Alg: 2
#
#
#             Scale: 200
#             Test: 1
#             Alg: 3
#
#
#             Scale: 200
#             Test: 1
#             Alg: 4
#
#
#             Scale: 200
#             Test: 2
#             Alg: 0
#
#
#             Scale: 200
#             Test: 2
#             Alg: 1
#
#
#             Scale: 200
#             Test: 2
#             Alg: 2
#
#
#             Scale: 200
#             Test: 2
#             Alg: 3
#
#
#             Scale: 200
#             Test: 2
#             Alg: 4
#
#
#             Scale: 200
#             Test: 3
#             Alg: 0
#
#
#             Scale: 200
#             Test: 3
#             Alg: 1
#
#
#             Scale: 200
#             Test: 3
#             Alg: 2
#
#
#             Scale: 200
#             Test: 3
#             Alg: 3
#
#
#             Scale: 200
#             Test: 3
#             Alg: 4
#
#
#             Scale: 200
#             Test: 4
#             Alg: 0
#
#
#             Scale: 200
#             Test: 4
#             Alg: 1
#
#
#             Scale: 200
#             Test: 4
#             Alg: 2
#
#
#             Scale: 200
#             Test: 4
#             Alg: 3
#
#
#             Scale: 200
#             Test: 4
#             Alg: 4
#
#
#             Scale: 200
#             Test: 5
#             Alg: 0
#
#
#             Scale: 200
#             Test: 5
#             Alg: 1
#
#
#             Scale: 200
#             Test: 5
#             Alg: 2
#
#
#             Scale: 200
#             Test: 5
#             Alg: 3
#
#
#             Scale: 200
#             Test: 5
#             Alg: 4
#
#
#             Scale: 200
#             Test: 6
#             Alg: 0
#
#
#             Scale: 200
#             Test: 6
#             Alg: 1
#
#
#             Scale: 200
#             Test: 6
#             Alg: 2
#
#
#             Scale: 200
#             Test: 6
#             Alg: 3
#
#
#             Scale: 200
#             Test: 6
#             Alg: 4
#
#
#             Scale: 200
#             Test: 7
#             Alg: 0
#
#
#             Scale: 200
#             Test: 7
#             Alg: 1
#
#
#             Scale: 200
#             Test: 7
#             Alg: 2
#
#
#             Scale: 200
#             Test: 7
#             Alg: 3
#
#
#             Scale: 200
#             Test: 7
#             Alg: 4
#
#
#             Scale: 200
#             Test: 8
#             Alg: 0
#
#
#             Scale: 200
#             Test: 8
#             Alg: 1
#
#
#             Scale: 200
#             Test: 8
#             Alg: 2
#
#
#             Scale: 200
#             Test: 8
#             Alg: 3
#
#
#             Scale: 200
#             Test: 8
#             Alg: 4
#
#
#             Scale: 200
#             Test: 9
#             Alg: 0
#
#
#             Scale: 200
#             Test: 9
#             Alg: 1
#
#
#             Scale: 200
#             Test: 9
#             Alg: 2
#
#
#             Scale: 200
#             Test: 9
#             Alg: 3
#
#
#             Scale: 200
#             Test: 9
#             Alg: 4
#
#
#             Scale: 400
#             Test: 0
#             Alg: 0
#
#
#             Scale: 400
#             Test: 0
#             Alg: 1
#
#
#             Scale: 400
#             Test: 0
#             Alg: 2
#
#
#             Scale: 400
#             Test: 0
#             Alg: 3
#
#
#             Scale: 400
#             Test: 0
#             Alg: 4
#
#
#             Scale: 400
#             Test: 1
#             Alg: 0
#
#
#             Scale: 400
#             Test: 1
#             Alg: 1
#
#
#             Scale: 400
#             Test: 1
#             Alg: 2
#
#
#             Scale: 400
#             Test: 1
#             Alg: 3
#
#
#             Scale: 400
#             Test: 1
#             Alg: 4
#
#
#             Scale: 400
#             Test: 2
#             Alg: 0
#
#
#             Scale: 400
#             Test: 2
#             Alg: 1
#
#
#             Scale: 400
#             Test: 2
#             Alg: 2
#
#
#             Scale: 400
#             Test: 2
#             Alg: 3
#
#
#             Scale: 400
#             Test: 2
#             Alg: 4
#
#
#             Scale: 400
#             Test: 3
#             Alg: 0
#
#
#             Scale: 400
#             Test: 3
#             Alg: 1
#
#
#             Scale: 400
#             Test: 3
#             Alg: 2
#
#
#             Scale: 400
#             Test: 3
#             Alg: 3
#
#
#             Scale: 400
#             Test: 3
#             Alg: 4
#
#
#             Scale: 400
#             Test: 4
#             Alg: 0
#
#
#             Scale: 400
#             Test: 4
#             Alg: 1
#
#
#             Scale: 400
#             Test: 4
#             Alg: 2
#
#
#             Scale: 400
#             Test: 4
#             Alg: 3
#
#
#             Scale: 400
#             Test: 4
#             Alg: 4
#
#
#             Scale: 400
#             Test: 5
#             Alg: 0
#
#
#             Scale: 400
#             Test: 5
#             Alg: 1
#
#
#             Scale: 400
#             Test: 5
#             Alg: 2
#
#
#             Scale: 400
#             Test: 5
#             Alg: 3
#
#
#             Scale: 400
#             Test: 5
#             Alg: 4
#
#
#             Scale: 400
#             Test: 6
#             Alg: 0
#
#
#             Scale: 400
#             Test: 6
#             Alg: 1
#
#
#             Scale: 400
#             Test: 6
#             Alg: 2
#
#
#             Scale: 400
#             Test: 6
#             Alg: 3
#
#
#             Scale: 400
#             Test: 6
#             Alg: 4
#
#
#             Scale: 400
#             Test: 7
#             Alg: 0
#
#
#             Scale: 400
#             Test: 7
#             Alg: 1
#
#
#             Scale: 400
#             Test: 7
#             Alg: 2
#
#
#             Scale: 400
#             Test: 7
#             Alg: 3
#
#
#             Scale: 400
#             Test: 7
#             Alg: 4
#
#
#             Scale: 400
#             Test: 8
#             Alg: 0
#
#
#             Scale: 400
#             Test: 8
#             Alg: 1
#
#
#             Scale: 400
#             Test: 8
#             Alg: 2
#
#
#             Scale: 400
#             Test: 8
#             Alg: 3
#
#
#             Scale: 400
#             Test: 8
#             Alg: 4
#
#
#             Scale: 400
#             Test: 9
#             Alg: 0
#
#
#             Scale: 400
#             Test: 9
#             Alg: 1
#
#
#             Scale: 400
#             Test: 9
#             Alg: 2
#
#
#             Scale: 400
#             Test: 9
#             Alg: 3
#
#
#             Scale: 400
#             Test: 9
#             Alg: 4
#
#
#             Scale: 600
#             Test: 0
#             Alg: 0
#
#
#             Scale: 600
#             Test: 0
#             Alg: 1
#
#
#             Scale: 600
#             Test: 0
#             Alg: 2
#
#
#             Scale: 600
#             Test: 0
#             Alg: 3
#
#
#             Scale: 600
#             Test: 0
#             Alg: 4
#
#
#             Scale: 600
#             Test: 1
#             Alg: 0
#
#
#             Scale: 600
#             Test: 1
#             Alg: 1
#
#
#             Scale: 600
#             Test: 1
#             Alg: 2
#
#
#             Scale: 600
#             Test: 1
#             Alg: 3
#
#
#             Scale: 600
#             Test: 1
#             Alg: 4
#
#
#             Scale: 600
#             Test: 2
#             Alg: 0
#
#
#             Scale: 600
#             Test: 2
#             Alg: 1
#
#
#             Scale: 600
#             Test: 2
#             Alg: 2
#
#
#             Scale: 600
#             Test: 2
#             Alg: 3
#
#
#             Scale: 600
#             Test: 2
#             Alg: 4
#
#
#             Scale: 600
#             Test: 3
#             Alg: 0
#
#
#             Scale: 600
#             Test: 3
#             Alg: 1
#
#
#             Scale: 600
#             Test: 3
#             Alg: 2
#
#
#             Scale: 600
#             Test: 3
#             Alg: 3
#
#
#             Scale: 600
#             Test: 3
#             Alg: 4
#
#
#             Scale: 600
#             Test: 4
#             Alg: 0
#
#
#             Scale: 600
#             Test: 4
#             Alg: 1
#
#
#             Scale: 600
#             Test: 4
#             Alg: 2
#
#
#             Scale: 600
#             Test: 4
#             Alg: 3
#
#
#             Scale: 600
#             Test: 4
#             Alg: 4
#
#
#             Scale: 600
#             Test: 5
#             Alg: 0
#
#
#             Scale: 600
#             Test: 5
#             Alg: 1
#
#
#             Scale: 600
#             Test: 5
#             Alg: 2
#
#
#             Scale: 600
#             Test: 5
#             Alg: 3
#
#
#             Scale: 600
#             Test: 5
#             Alg: 4
#
#
#             Scale: 600
#             Test: 6
#             Alg: 0
#
#
#             Scale: 600
#             Test: 6
#             Alg: 1
#
#
#             Scale: 600
#             Test: 6
#             Alg: 2
#
#
#             Scale: 600
#             Test: 6
#             Alg: 3
#
#
#             Scale: 600
#             Test: 6
#             Alg: 4
#
#
#             Scale: 600
#             Test: 7
#             Alg: 0
#
#
#             Scale: 600
#             Test: 7
#             Alg: 1
#
#
#             Scale: 600
#             Test: 7
#             Alg: 2
#
#
#             Scale: 600
#             Test: 7
#             Alg: 3
#
#
#             Scale: 600
#             Test: 7
#             Alg: 4
#
#
#             Scale: 600
#             Test: 8
#             Alg: 0
#
#
#             Scale: 600
#             Test: 8
#             Alg: 1
#
#
#             Scale: 600
#             Test: 8
#             Alg: 2
#
#
#             Scale: 600
#             Test: 8
#             Alg: 3
#
#
#             Scale: 600
#             Test: 8
#             Alg: 4
#
#
#             Scale: 600
#             Test: 9
#             Alg: 0
#
#
#             Scale: 600
#             Test: 9
#             Alg: 1
#
#
#             Scale: 600
#             Test: 9
#             Alg: 2
#
#
#             Scale: 600
#             Test: 9
#             Alg: 3
#
#
#             Scale: 600
#             Test: 9
#             Alg: 4
#
#
#             Scale: 800
#             Test: 0
#             Alg: 0
#
#
#             Scale: 800
#             Test: 0
#             Alg: 1
#
#
#             Scale: 800
#             Test: 0
#             Alg: 2
#
#
#             Scale: 800
#             Test: 0
#             Alg: 3
#
#
#             Scale: 800
#             Test: 0
#             Alg: 4
#
#
#             Scale: 800
#             Test: 1
#             Alg: 0
#
#
#             Scale: 800
#             Test: 1
#             Alg: 1
#
#
#             Scale: 800
#             Test: 1
#             Alg: 2
#
#
#             Scale: 800
#             Test: 1
#             Alg: 3
#
#
#             Scale: 800
#             Test: 1
#             Alg: 4
#
#
#             Scale: 800
#             Test: 2
#             Alg: 0
#
#
#             Scale: 800
#             Test: 2
#             Alg: 1
#
#
#             Scale: 800
#             Test: 2
#             Alg: 2
#
#
#             Scale: 800
#             Test: 2
#             Alg: 3
#
#
#             Scale: 800
#             Test: 2
#             Alg: 4
#
#
#             Scale: 800
#             Test: 3
#             Alg: 0
#
#
#             Scale: 800
#             Test: 3
#             Alg: 1
#
#
#             Scale: 800
#             Test: 3
#             Alg: 2
#
#
#             Scale: 800
#             Test: 3
#             Alg: 3
#
#
#             Scale: 800
#             Test: 3
#             Alg: 4
#
#
#             Scale: 800
#             Test: 4
#             Alg: 0
#
#
#             Scale: 800
#             Test: 4
#             Alg: 1
#
#
#             Scale: 800
#             Test: 4
#             Alg: 2
#
#
#             Scale: 800
#             Test: 4
#             Alg: 3
#
#
#             Scale: 800
#             Test: 4
#             Alg: 4
#
#
#             Scale: 800
#             Test: 5
#             Alg: 0
#
#
#             Scale: 800
#             Test: 5
#             Alg: 1
#
#
#             Scale: 800
#             Test: 5
#             Alg: 2
#
#
#             Scale: 800
#             Test: 5
#             Alg: 3
#
#
#             Scale: 800
#             Test: 5
#             Alg: 4
#
#
#             Scale: 800
#             Test: 6
#             Alg: 0
#
#
#             Scale: 800
#             Test: 6
#             Alg: 1
#
#
#             Scale: 800
#             Test: 6
#             Alg: 2
#
#
#             Scale: 800
#             Test: 6
#             Alg: 3
#
#
#             Scale: 800
#             Test: 6
#             Alg: 4
#
#
#             Scale: 800
#             Test: 7
#             Alg: 0
#
#
#             Scale: 800
#             Test: 7
#             Alg: 1
#
#
#             Scale: 800
#             Test: 7
#             Alg: 2
#
#
#             Scale: 800
#             Test: 7
#             Alg: 3
#
#
#             Scale: 800
#             Test: 7
#             Alg: 4
#
#
#             Scale: 800
#             Test: 8
#             Alg: 0
#
#
#             Scale: 800
#             Test: 8
#             Alg: 1
#
#
#             Scale: 800
#             Test: 8
#             Alg: 2
#
#
#             Scale: 800
#             Test: 8
#             Alg: 3
#
#
#             Scale: 800
#             Test: 8
#             Alg: 4
#
#
#             Scale: 800
#             Test: 9
#             Alg: 0
#
#
#             Scale: 800
#             Test: 9
#             Alg: 1
#
#
#             Scale: 800
#             Test: 9
#             Alg: 2
#
#
#             Scale: 800
#             Test: 9
#             Alg: 3
#
#
#             Scale: 800
#             Test: 9
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 0
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 0
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 0
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 0
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 0
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 1
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 1
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 1
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 1
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 1
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 2
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 2
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 2
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 2
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 2
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 3
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 3
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 3
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 3
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 3
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 4
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 4
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 4
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 4
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 4
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 5
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 5
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 5
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 5
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 5
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 6
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 6
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 6
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 6
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 6
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 7
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 7
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 7
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 7
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 7
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 8
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 8
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 8
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 8
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 8
#             Alg: 4
#
#
#             Scale: 1000
#             Test: 9
#             Alg: 0
#
#
#             Scale: 1000
#             Test: 9
#             Alg: 1
#
#
#             Scale: 1000
#             Test: 9
#             Alg: 2
#
#
#             Scale: 1000
#             Test: 9
#             Alg: 3
#
#
#             Scale: 1000
#             Test: 9
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 0
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 0
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 0
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 0
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 0
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 1
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 1
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 1
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 1
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 1
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 2
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 2
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 2
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 2
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 2
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 3
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 3
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 3
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 3
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 3
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 4
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 4
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 4
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 4
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 4
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 5
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 5
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 5
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 5
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 5
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 6
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 6
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 6
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 6
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 6
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 7
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 7
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 7
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 7
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 7
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 8
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 8
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 8
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 8
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 8
#             Alg: 4
#
#
#             Scale: 1200
#             Test: 9
#             Alg: 0
#
#
#             Scale: 1200
#             Test: 9
#             Alg: 1
#
#
#             Scale: 1200
#             Test: 9
#             Alg: 2
#
#
#             Scale: 1200
#             Test: 9
#             Alg: 3
#
#
#             Scale: 1200
#             Test: 9
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 0
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 0
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 0
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 0
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 0
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 1
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 1
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 1
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 1
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 1
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 2
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 2
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 2
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 2
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 2
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 3
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 3
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 3
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 3
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 3
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 4
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 4
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 4
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 4
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 4
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 5
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 5
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 5
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 5
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 5
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 6
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 6
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 6
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 6
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 6
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 7
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 7
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 7
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 7
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 7
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 8
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 8
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 8
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 8
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 8
#             Alg: 4
#
#
#             Scale: 1400
#             Test: 9
#             Alg: 0
#
#
#             Scale: 1400
#             Test: 9
#             Alg: 1
#
#
#             Scale: 1400
#             Test: 9
#             Alg: 2
#
#
#             Scale: 1400
#             Test: 9
#             Alg: 3
#
#
#             Scale: 1400
#             Test: 9
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 0
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 0
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 0
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 0
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 0
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 1
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 1
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 1
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 1
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 1
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 2
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 2
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 2
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 2
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 2
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 3
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 3
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 3
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 3
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 3
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 4
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 4
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 4
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 4
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 4
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 5
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 5
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 5
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 5
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 5
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 6
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 6
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 6
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 6
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 6
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 7
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 7
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 7
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 7
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 7
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 8
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 8
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 8
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 8
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 8
#             Alg: 4
#
#
#             Scale: 1600
#             Test: 9
#             Alg: 0
#
#
#             Scale: 1600
#             Test: 9
#             Alg: 1
#
#
#             Scale: 1600
#             Test: 9
#             Alg: 2
#
#
#             Scale: 1600
#             Test: 9
#             Alg: 3
#
#
#             Scale: 1600
#             Test: 9
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 0
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 0
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 0
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 0
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 0
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 1
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 1
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 1
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 1
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 1
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 2
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 2
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 2
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 2
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 2
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 3
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 3
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 3
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 3
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 3
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 4
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 4
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 4
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 4
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 4
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 5
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 5
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 5
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 5
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 5
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 6
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 6
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 6
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 6
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 6
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 7
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 7
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 7
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 7
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 7
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 8
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 8
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 8
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 8
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 8
#             Alg: 4
#
#
#             Scale: 1800
#             Test: 9
#             Alg: 0
#
#
#             Scale: 1800
#             Test: 9
#             Alg: 1
#
#
#             Scale: 1800
#             Test: 9
#             Alg: 2
#
#
#             Scale: 1800
#             Test: 9
#             Alg: 3
#
#
#             Scale: 1800
#             Test: 9
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 0
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 0
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 0
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 0
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 0
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 1
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 1
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 1
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 1
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 1
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 2
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 2
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 2
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 2
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 2
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 3
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 3
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 3
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 3
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 3
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 4
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 4
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 4
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 4
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 4
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 5
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 5
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 5
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 5
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 5
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 6
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 6
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 6
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 6
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 6
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 7
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 7
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 7
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 7
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 7
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 8
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 8
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 8
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 8
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 8
#             Alg: 4
#
#
#             Scale: 2000
#             Test: 9
#             Alg: 0
#
#
#             Scale: 2000
#             Test: 9
#             Alg: 1
#
#
#             Scale: 2000
#             Test: 9
#             Alg: 2
#
#
#             Scale: 2000
#             Test: 9
#             Alg: 3
#
#
#             Scale: 2000
#             Test: 9
#             Alg: 4

# %%
# Get the record and plot the result
avgTimeArr=np.zeros((5,10))
for algId in range(5):
    for scaleId in range(10):
        avgTimeArr[algId,scaleId] = timeArr[scaleId,:,algId].mean()
    plt.plot(scaleLst, avgTimeArr[algId,:])

with open('time.csv','w',encoding='utf-8') as f:
    time_csv=csv.writer(f)
    time_csv.writerows(avgTimeArr)






# scale=2000
# # Initialize random array
# fD = [random.randint(-1e5,1e5) for _ in range(scale)]
# # Initialize Alg Class with iNum and fD
# MycAlg = cAlg(scale,fD)


# MycAlg.Alg_Sort1()
# print(MycAlg.fD)
# print(MycAlg.fD==sorted(MycAlg.fD))

# %%
# Get the record and plot the result
avgTimeArr=np.zeros((5,10))
for algId in range(5):
    for scaleId in range(10):
        avgTimeArr[algId,scaleId] = timeArr[scaleId,:,algId].mean()
    plt.plot(scaleLst, avgTimeArr[algId,:])

with open(f'time{str(random.randint(1,1e5))}.csv','x',encoding='utf-8') as f:
    time_csv=csv.writer(f)
    time_csv.writerows(avgTimeArr)






# scale=2000
# # Initialize random array
# fD = [random.randint(-1e5,1e5) for _ in range(scale)]
# # Initialize Alg Class with iNum and fD
# MycAlg = cAlg(scale,fD)


# MycAlg.Alg_Sort1()
# print(MycAlg.fD)
# print(MycAlg.fD==sorted(MycAlg.fD))
